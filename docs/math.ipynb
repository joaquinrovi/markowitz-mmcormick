# %%
# -*- coding: utf-8 -*-
"""
math.ipynb
====================================
Basic script to create the mathematical model (no best practices)

@author:
     - j.rodriguez.villegas
"""
# Out:
# '\nmath.ipynb\n====================================\nBasic script to create the mathematical model (no best practices)\n\n@author:\n     - j.rodriguez.villegas\n'

# %%
# Coding the convex relaxed linear problem using Pyomo

#Import the libraries

import numpy as np
import pandas as pd
import pyomo.environ as pe
import pyomo.opt as po
import matplotlib.pyplot as plt

from pyomo.environ import *

# %%
# Declare the path to read the data
url = 'C:/Users/j.rodriguez.villegas/Documents/optimization/01_data/configuration_file.xlsx'

# Read the data
df = pd.read_excel(url, sheet_name = 'Historical_data')
df.head(15)
# Out:
#          Date Asset       Open       High        Low      Close  Adj Close  \
# 0  2013-09-01  AAPL  17.610000  18.140000  15.970000  17.030000  14.860000
# 1  2013-09-01   ACN  72.720001  78.339996  72.360001  73.639999  61.282059
# 2  2013-09-01  AMZN  14.236500  16.028500  14.208500  15.632000  15.632000
# 3  2013-09-01  GOOG  21.279240  22.565170  21.269028  21.815977  21.815977
# 4  2013-09-01   SLB  81.690002  89.720001  81.680000  88.360001  67.575027
# 5  2013-09-01  TSLA  11.560000  12.966667  10.567333  12.891333  12.891333
# 6  2013-09-01  META  41.840000  51.599998  41.439999  50.230000  50.230000
# 7  2013-09-01   CRM  49.459999  54.250000  48.020000  51.910000  51.910000
# 8  2013-09-01     V  44.007500  50.215000  43.762501  47.775002  44.554924
# 9  2013-09-01    KR  18.485001  20.709999  18.355000  20.170000  16.831999
# 10 2013-09-01   MCD  95.099998  98.989998  94.120003  96.209999  73.696480
# 11 2013-09-01    KO  38.270000  39.669998  37.750000  37.880001  27.622013
# 12 2013-09-01   JPM  51.250000  53.930000  50.060001  51.689999  39.099617
# 13 2013-09-01   JNJ  86.889999  90.720001  86.000000  86.690002  66.100693
# 14 2013-09-01   PFE  26.925997  27.770397  26.432638  27.258064  18.945776
#
#         Volume       ROI
# 0   8630941200 -0.156161
# 1     70562800 -0.157287
# 2    869376000  0.098023
# 3   1329906200  0.025224
# 4    126421200 -0.172787
# 5   2568159000  0.115167
# 6   1583083800  0.200526
# 7    105773900  0.049535
# 8    284857200  0.012439
# 9    176151400 -0.089424
# 10    83958900 -0.225063
# 11   300960000 -0.278233
# 12   434870300 -0.237081
# 13   158876500 -0.239260
# 14   535658293 -0.296376

# %%
# Create a pivot table
pivot_table = df.pivot(index="Date", columns="Asset", values="ROI")

# Calculate the covariance between asset returns (ROI)
covariance_matrix = pivot_table.cov()

# Get the list of unique assets
assets = df["Asset"].unique()

# Calculate and print the covariances for all combinations of products
for i in range(len(assets)):
    for j in range(i, len(assets)):
        asset1 = assets[i]
        asset2 = assets[j]
        covariance_prod = covariance_matrix.loc[asset1, asset2]
        print(f"Covariance ({asset1}, {asset2}): {covariance_prod}")
# Out:
# Covariance (AAPL, AAPL): 0.007658807899858534
# Covariance (AAPL, ACN): 0.004612144424585366
# Covariance (AAPL, AMZN): 0.0036719723431893514
# Covariance (AAPL, GOOG): 0.0025955994570200686
# Covariance (AAPL, SLB): 0.0059025741036425544
# Covariance (AAPL, TSLA): 0.00766830703283334
# Covariance (AAPL, META): 0.002543971160575094
# Covariance (AAPL, CRM): 0.0034786148782684784
# Covariance (AAPL, V): 0.0028583420542757036
# Covariance (AAPL, KR): 0.00315773931973825
# Covariance (AAPL, MCD): 0.004079759250905865
# Covariance (AAPL, KO): 0.004233695115418182
# Covariance (AAPL, JPM): 0.004132232769104707
# Covariance (AAPL, JNJ): 0.0038455600262075813
# Covariance (AAPL, PFE): 0.004460370781113621
# Covariance (AAPL, MSFT): 0.004667346350022258
# Covariance (AAPL, TIP): 0.002480175859271698
# Covariance (ACN, ACN): 0.005490736928362164
# Covariance (ACN, AMZN): 0.002513941921629538
# Covariance (ACN, GOOG): 0.002519103051335982
# Covariance (ACN, SLB): 0.00597121875715909
# Covariance (ACN, TSLA): 0.004590066523200945
# Covariance (ACN, META): 0.002383964933219802
# Covariance (ACN, CRM): 0.00257349547283499
# Covariance (ACN, V): 0.0027503191400089057
# Covariance (ACN, KR): 0.003157410493208695
# Covariance (ACN, MCD): 0.004500544043239776
# Covariance (ACN, KO): 0.004653688200457242
# Covariance (ACN, JPM): 0.00478198092227744
# Covariance (ACN, JNJ): 0.003888938223235731
# Covariance (ACN, PFE): 0.005210679791710279
# Covariance (ACN, MSFT): 0.004256730728673755
# Covariance (ACN, TIP): 0.0026298364384594927
# Covariance (AMZN, AMZN): 0.008428022180392373
# Covariance (AMZN, GOOG): 0.0042312804229432685
# Covariance (AMZN, SLB): 0.0009727290523884733
# Covariance (AMZN, TSLA): 0.006897736126067667
# Covariance (AMZN, META): 0.003973223147359008
# Covariance (AMZN, CRM): 0.004755180130802377
# Covariance (AMZN, V): 0.0023972982463427933
# Covariance (AMZN, KR): 0.0008668039341389225
# Covariance (AMZN, MCD): 0.0005769760636443023
# Covariance (AMZN, KO): -0.00022332058731969727
# Covariance (AMZN, JPM): 0.000636576736074311
# Covariance (AMZN, JNJ): 0.00022789025281404803
# Covariance (AMZN, PFE): 0.0003685147028798871
# Covariance (AMZN, MSFT): 0.0028577688481396988
# Covariance (AMZN, TIP): -0.0001384560073917013
# Covariance (GOOG, GOOG): 0.004888483863980565
# Covariance (GOOG, SLB): 0.002328092000915229
# Covariance (GOOG, TSLA): 0.004560551281360168
# Covariance (GOOG, META): 0.003614791211960853
# Covariance (GOOG, CRM): 0.0036645868400875135
# Covariance (GOOG, V): 0.0020879730162799617
# Covariance (GOOG, KR): 0.001013696344209149
# Covariance (GOOG, MCD): 0.0010459930327362593
# Covariance (GOOG, KO): 0.0009868673664704842
# Covariance (GOOG, JPM): 0.0015299469841565088
# Covariance (GOOG, JNJ): 0.0006930472765426335
# Covariance (GOOG, PFE): 0.0009156646114713578
# Covariance (GOOG, MSFT): 0.002594966980767524
# Covariance (GOOG, TIP): 0.0002456557586705798
# Covariance (SLB, SLB): 0.019431269116218484
# Covariance (SLB, TSLA): 0.0054233117020872
# Covariance (SLB, META): 0.0013904300351764072
# Covariance (SLB, CRM): 0.002347864410014888
# Covariance (SLB, V): 0.004281778948873735
# Covariance (SLB, KR): 0.004841932451637618
# Covariance (SLB, MCD): 0.007072209190028039
# Covariance (SLB, KO): 0.008497508468222989
# Covariance (SLB, JPM): 0.010296597436671088
# Covariance (SLB, JNJ): 0.007259197771979465
# Covariance (SLB, PFE): 0.008463951179622438
# Covariance (SLB, MSFT): 0.0050586743239068675
# Covariance (SLB, TIP): 0.004993780158700596
# Covariance (TSLA, TSLA): 0.032063780016992664
# Covariance (TSLA, META): 0.006281027272067908
# Covariance (TSLA, CRM): 0.008793258515656127
# Covariance (TSLA, V): 0.0033526749499047633
# Covariance (TSLA, KR): 0.0019917337737152385
# Covariance (TSLA, MCD): 0.0027852105166036594
# Covariance (TSLA, KO): 0.002060634635783827
# Covariance (TSLA, JPM): 0.0029545848094885982
# Covariance (TSLA, JNJ): 0.002193420285887694
# Covariance (TSLA, PFE): 0.0018093769443959307
# Covariance (TSLA, MSFT): 0.0047536333144688695
# Covariance (TSLA, TIP): 0.001103878911408475
# Covariance (META, META): 0.009748848769885698
# Covariance (META, CRM): 0.0038937307245728746
# Covariance (META, V): 0.0020393382550989592
# Covariance (META, KR): 0.0007461341353545231
# Covariance (META, MCD): 0.0005279495690795047
# Covariance (META, KO): 0.0002633323431833792
# Covariance (META, JPM): 0.0010099829021387233
# Covariance (META, JNJ): 0.0001883534227808842
# Covariance (META, PFE): 0.00018298601035753249
# Covariance (META, MSFT): 0.002155129052512411
# Covariance (META, TIP): 0.00017785110959077095
# Covariance (CRM, CRM): 0.0072680277016543724
# Covariance (CRM, V): 0.002655831208670607
# Covariance (CRM, KR): 0.0008896708945162075
# Covariance (CRM, MCD): 0.0013323031125431835
# Covariance (CRM, KO): 0.000566683483480557
# Covariance (CRM, JPM): 0.001576073978349987
# Covariance (CRM, JNJ): 0.0005300132220614498
# Covariance (CRM, PFE): 0.0004836082928111051
# Covariance (CRM, MSFT): 0.0028648517158688753
# Covariance (CRM, TIP): 0.00033462336797460444
# Covariance (V, V): 0.00347475849367559
# Covariance (V, KR): 0.0012024780434834314
# Covariance (V, MCD): 0.002368964354006393
# Covariance (V, KO): 0.0023718412447167082
# Covariance (V, JPM): 0.0026571312385900094
# Covariance (V, JNJ): 0.0018831242890916461
# Covariance (V, PFE): 0.0019886722857345752
# Covariance (V, MSFT): 0.002238131638148277
# Covariance (V, TIP): 0.0010492039957230343
# Covariance (KR, KR): 0.007034548708608947
# Covariance (KR, MCD): 0.0035129082081618306
# Covariance (KR, KO): 0.004119847909475717
# Covariance (KR, JPM): 0.003497058210011221
# Covariance (KR, JNJ): 0.003721863200407072
# Covariance (KR, PFE): 0.0047119636899614565
# Covariance (KR, MSFT): 0.002803385287605173
# Covariance (KR, TIP): 0.002700462461107876
# Covariance (MCD, MCD): 0.006419819433380597
# Covariance (MCD, KO): 0.00645588966593022
# Covariance (MCD, JPM): 0.005490282175343142
# Covariance (MCD, JNJ): 0.005370492096917996
# Covariance (MCD, PFE): 0.006528645511375006
# Covariance (MCD, MSFT): 0.004224136573257412
# Covariance (MCD, TIP): 0.0037443472874600695
# Covariance (KO, KO): 0.008009506076622132
# Covariance (KO, JPM): 0.006247819908344231
# Covariance (KO, JNJ): 0.00615936440642072
# Covariance (KO, PFE): 0.007350838788875096
# Covariance (KO, MSFT): 0.004467138312332603
# Covariance (KO, TIP): 0.0044931900661154475
# Covariance (JPM, JPM): 0.008328209728551117
# Covariance (JPM, JNJ): 0.005322553472715243
# Covariance (JPM, PFE): 0.006679483195591078
# Covariance (JPM, MSFT): 0.004421786522359775
# Covariance (JPM, TIP): 0.0037604563267373313
# Covariance (JNJ, JNJ): 0.005989129835237947
# Covariance (JNJ, PFE): 0.006731626965886345
# Covariance (JNJ, MSFT): 0.003985911235411555
# Covariance (JNJ, TIP): 0.0036256230068057458
# Covariance (PFE, PFE): 0.010079166012371701
# Covariance (PFE, MSFT): 0.004725657688951169
# Covariance (PFE, TIP): 0.004619732697986545
# Covariance (MSFT, MSFT): 0.005596348167261328
# Covariance (MSFT, TIP): 0.00257720151504101
# Covariance (TIP, TIP): 0.00334628497971567

# %%
# Create a pivot table
pivot_table = df.pivot(index="Date", columns="Asset", values="ROI")

# Calculate the correlation between asset returns (ROI)
correlation_matrix = pivot_table.corr()

# Get the list of unique assets
assets = df["Asset"].unique()

# Calculate and print the covariances for all combinations of products
for i in range(len(assets)):
    for j in range(i, len(assets)):
        asset1 = assets[i]
        asset2 = assets[j]
        correlation_prod = correlation_matrix.loc[asset1, asset2]
        print(f"Covariance ({asset1}, {asset2}): {correlation_prod}")
# Out:
# Covariance (AAPL, AAPL): 1.0
# Covariance (AAPL, ACN): 0.711224963834698
# Covariance (AAPL, AMZN): 0.4570418597656518
# Covariance (AAPL, GOOG): 0.4241993447622395
# Covariance (AAPL, SLB): 0.48384947762232816
# Covariance (AAPL, TSLA): 0.48934093215844954
# Covariance (AAPL, META): 0.2944116076012564
# Covariance (AAPL, CRM): 0.4662485292659837
# Covariance (AAPL, V): 0.5540784995982042
# Covariance (AAPL, KR): 0.4302070925734238
# Covariance (AAPL, MCD): 0.5818252181656142
# Covariance (AAPL, KO): 0.5405503136865245
# Covariance (AAPL, JPM): 0.5174023088580576
# Covariance (AAPL, JNJ): 0.567802293524419
# Covariance (AAPL, PFE): 0.5076659957544485
# Covariance (AAPL, MSFT): 0.7129138939298474
# Covariance (AAPL, TIP): 0.48991464915922556
# Covariance (ACN, ACN): 1.0
# Covariance (ACN, AMZN): 0.36955330196564967
# Covariance (ACN, GOOG): 0.48623198373024357
# Covariance (ACN, SLB): 0.5780921611979002
# Covariance (ACN, TSLA): 0.34593643174689587
# Covariance (ACN, META): 0.3258426116725745
# Covariance (ACN, CRM): 0.4073800934509808
# Covariance (ACN, V): 0.6296590654045396
# Covariance (ACN, KR): 0.5080396512434341
# Covariance (ACN, MCD): 0.7580333123317001
# Covariance (ACN, KO): 0.7017446271780173
# Covariance (ACN, JPM): 0.7071583833241165
# Covariance (ACN, JNJ): 0.6781626420880935
# Covariance (ACN, PFE): 0.7004332726836161
# Covariance (ACN, MSFT): 0.7679067720826492
# Covariance (ACN, TIP): 0.6135245681067935
# Covariance (AMZN, AMZN): 1.0
# Covariance (AMZN, GOOG): 0.659207106664151
# Covariance (AMZN, SLB): 0.07601135401466695
# Covariance (AMZN, TSLA): 0.4196008712440404
# Covariance (AMZN, META): 0.43833228082249787
# Covariance (AMZN, CRM): 0.6075693419477347
# Covariance (AMZN, V): 0.44299305756033397
# Covariance (AMZN, KR): 0.11257447188759992
# Covariance (AMZN, MCD): 0.07843927211866698
# Covariance (AMZN, KO): -0.027180851560021226
# Covariance (AMZN, JPM): 0.07598224154052542
# Covariance (AMZN, JNJ): 0.03207606251536385
# Covariance (AMZN, PFE): 0.03998339668546272
# Covariance (AMZN, MSFT): 0.41611359024816497
# Covariance (AMZN, TIP): -0.026071589343862743
# Covariance (GOOG, GOOG): 1.0
# Covariance (GOOG, SLB): 0.2388704690439424
# Covariance (GOOG, TSLA): 0.36426956775957203
# Covariance (GOOG, META): 0.5236238964508968
# Covariance (GOOG, CRM): 0.6147940244928642
# Covariance (GOOG, V): 0.5066120042072475
# Covariance (GOOG, KR): 0.1728632471316613
# Covariance (GOOG, MCD): 0.18671546570830314
# Covariance (GOOG, KO): 0.15771348463107368
# Covariance (GOOG, JPM): 0.2397802795322968
# Covariance (GOOG, JNJ): 0.12808371164843144
# Covariance (GOOG, PFE): 0.13044788367631185
# Covariance (GOOG, MSFT): 0.49612644901030173
# Covariance (GOOG, TIP): 0.060737707298369976
# Covariance (SLB, SLB): 1.0
# Covariance (SLB, TSLA): 0.21727343106507493
# Covariance (SLB, META): 0.10102337899153245
# Covariance (SLB, CRM): 0.19756688040344694
# Covariance (SLB, V): 0.5210883296117027
# Covariance (SLB, KR): 0.414142711443816
# Covariance (SLB, MCD): 0.6332032108214716
# Covariance (SLB, KO): 0.6811427762303437
# Covariance (SLB, JPM): 0.8094076850223482
# Covariance (SLB, JNJ): 0.6729087588508136
# Covariance (SLB, PFE): 0.6047978896937697
# Covariance (SLB, MSFT): 0.4851027922722598
# Covariance (SLB, TIP): 0.6192947154940828
# Covariance (TSLA, TSLA): 1.0
# Covariance (TSLA, META): 0.3552602787885016
# Covariance (TSLA, CRM): 0.576015532095522
# Covariance (TSLA, V): 0.3176301917904579
# Covariance (TSLA, KR): 0.13261901777543025
# Covariance (TSLA, MCD): 0.19412848249833914
# Covariance (TSLA, KO): 0.12858513571429597
# Covariance (TSLA, JPM): 0.18080618129461576
# Covariance (TSLA, JNJ): 0.15828240176291142
# Covariance (TSLA, PFE): 0.10064898341759154
# Covariance (TSLA, MSFT): 0.3548672779290964
# Covariance (TSLA, TIP): 0.10656942302572257
# Covariance (META, META): 1.0
# Covariance (META, CRM): 0.46257372497716487
# Covariance (META, V): 0.35038885732741076
# Covariance (META, KR): 0.0900994462854399
# Covariance (META, MCD): 0.06673510782394088
# Covariance (META, KO): 0.029800576746318152
# Covariance (META, JPM): 0.112088621552163
# Covariance (META, JNJ): 0.024649890020750704
# Covariance (META, PFE): 0.018459882077106658
# Covariance (META, MSFT): 0.2917724297678504
# Covariance (META, TIP): 0.031138554661178562
# Covariance (CRM, CRM): 1.0
# Covariance (CRM, V): 0.5284815990781965
# Covariance (CRM, KR): 0.12442366089977704
# Covariance (CRM, MCD): 0.19504433863997364
# Covariance (CRM, KO): 0.07427273222640993
# Covariance (CRM, JPM): 0.2025780960353989
# Covariance (CRM, JNJ): 0.08033347485735023
# Covariance (CRM, PFE): 0.05650321417038777
# Covariance (CRM, MSFT): 0.44920181064958115
# Covariance (CRM, TIP): 0.06785260364287775
# Covariance (V, V): 1.0
# Covariance (V, KR): 0.24321856512417483
# Covariance (V, MCD): 0.5015737584053215
# Covariance (V, KO): 0.4495939274374068
# Covariance (V, JPM): 0.4939407603136853
# Covariance (V, JNJ): 0.41279536139796036
# Covariance (V, PFE): 0.3360381689518283
# Covariance (V, MSFT): 0.5075407897022405
# Covariance (V, TIP): 0.3076919692017013
# Covariance (KR, KR): 1.0
# Covariance (KR, MCD): 0.5227418551304914
# Covariance (KR, KO): 0.5488582486773057
# Covariance (KR, JPM): 0.4568871189172711
# Covariance (KR, JNJ): 0.5734036085470986
# Covariance (KR, PFE): 0.5595920234848747
# Covariance (KR, MSFT): 0.4467991173119482
# Covariance (KR, TIP): 0.5565940533140215
# Covariance (MCD, MCD): 1.0
# Covariance (MCD, KO): 0.9003094845119335
# Covariance (MCD, JPM): 0.750857343358959
# Covariance (MCD, JNJ): 0.8661055294560882
# Covariance (MCD, PFE): 0.8116137244974695
# Covariance (MCD, MSFT): 0.7047323079694263
# Covariance (MCD, TIP): 0.807854696482373
# Covariance (KO, KO): 1.0
# Covariance (KO, JPM): 0.7649795198482496
# Covariance (KO, JNJ): 0.8893058872792473
# Covariance (KO, PFE): 0.8181288949981711
# Covariance (KO, MSFT): 0.6672278555344329
# Covariance (KO, TIP): 0.8679015428873852
# Covariance (JPM, JPM): 1.0
# Covariance (JPM, JNJ): 0.7536372262931673
# Covariance (JPM, PFE): 0.7290456712057238
# Covariance (JPM, MSFT): 0.6476935648166925
# Covariance (JPM, TIP): 0.7123333219292814
# Covariance (JNJ, JNJ): 1.0
# Covariance (JNJ, PFE): 0.8664148318851641
# Covariance (JNJ, MSFT): 0.6884832773993961
# Covariance (JNJ, TIP): 0.8098774710102873
# Covariance (PFE, PFE): 1.0
# Covariance (PFE, MSFT): 0.6292128706019015
# Covariance (PFE, TIP): 0.7954686827889366
# Covariance (MSFT, MSFT): 1.0
# Covariance (MSFT, TIP): 0.5955449593938529
# Covariance (TIP, TIP): 1.0

# %%
# Calculate the expected return for each asset
# Create a new DataFrame
assets_df = df.groupby("Asset")["ROI"].mean().reset_index()
assets_df.rename(columns={"ROI": "Mean (average) ROI"}, inplace=True)

assets_df.head(10)
# Out:
#   Asset  Mean (average) ROI
# 0  AAPL           -0.032118
# 1   ACN           -0.062954
# 2  AMZN            0.021541
# 3   CRM            0.015987
# 4  GOOG            0.018026
# 5   JNJ           -0.120664
# 6   JPM           -0.123991
# 7    KO           -0.136192
# 8    KR           -0.086542
# 9   MCD           -0.105444

# %%
# Optimization model (Convex linear relaxation)

assets_data = assets_df

# Sets
model = pe.ConcreteModel('markowitz')
model.assets = pe.Set(initialize = assets_data['Asset'].drop_duplicates())

assets_data = assets_data.set_index('Asset')

# %%
print("The number of elements in the set {model.assets} is: ", len(model.assets))
# Out:
# The number of elements in the set {model.assets} is:  17

# %%
# Parameters
model.return_level = pe.Param(initialize = 0.01)
model.risk_level = pe.Param(initialize = 0.005)
model.expected_return = pe.Param(model.assets, initialize = assets_data['Mean (average) ROI'].to_dict())

covariance_dict = {}
for i in range(len(assets)):
    for j in range(i, len(assets)):
        asset1 = assets[i]
        asset2 = assets[j]
        covariance_prod = covariance_matrix.loc[asset1, asset2]
        
        if asset1 not in covariance_dict:
            covariance_dict[asset1] = {}
        covariance_dict[asset1][asset2] = covariance_prod

model.covariance = pe.Param(model.assets, model.assets, initialize=0.0, mutable=True)

# Assign the covariance values to the parameter (product1, product2)
for asset1, covariance_i in covariance_dict.items():
    for asset2, covariance_prod in covariance_i.items():
        model.covariance[asset1, asset2] = covariance_prod

# %%
# Display the values of model.covariance parameter
for asset1 in model.assets:
    for asset2 in model.assets:
        covariance_param = model.covariance[asset1, asset2].value
        print(f"Covariance ({asset1}, {asset2}): {covariance_param:.8f}")
# Out:
# Covariance (AAPL, AAPL): 0.00765881
# Covariance (AAPL, ACN): 0.00461214
# Covariance (AAPL, AMZN): 0.00367197
# Covariance (AAPL, CRM): 0.00347861
# Covariance (AAPL, GOOG): 0.00259560
# Covariance (AAPL, JNJ): 0.00384556
# Covariance (AAPL, JPM): 0.00413223
# Covariance (AAPL, KO): 0.00423370
# Covariance (AAPL, KR): 0.00315774
# Covariance (AAPL, MCD): 0.00407976
# Covariance (AAPL, META): 0.00254397
# Covariance (AAPL, MSFT): 0.00466735
# Covariance (AAPL, PFE): 0.00446037
# Covariance (AAPL, SLB): 0.00590257
# Covariance (AAPL, TIP): 0.00248018
# Covariance (AAPL, TSLA): 0.00766831
# Covariance (AAPL, V): 0.00285834
# Covariance (ACN, AAPL): 0.00000000
# Covariance (ACN, ACN): 0.00549074
# Covariance (ACN, AMZN): 0.00251394
# Covariance (ACN, CRM): 0.00257350
# Covariance (ACN, GOOG): 0.00251910
# Covariance (ACN, JNJ): 0.00388894
# Covariance (ACN, JPM): 0.00478198
# Covariance (ACN, KO): 0.00465369
# Covariance (ACN, KR): 0.00315741
# Covariance (ACN, MCD): 0.00450054
# Covariance (ACN, META): 0.00238396
# Covariance (ACN, MSFT): 0.00425673
# Covariance (ACN, PFE): 0.00521068
# Covariance (ACN, SLB): 0.00597122
# Covariance (ACN, TIP): 0.00262984
# Covariance (ACN, TSLA): 0.00459007
# Covariance (ACN, V): 0.00275032
# Covariance (AMZN, AAPL): 0.00000000
# Covariance (AMZN, ACN): 0.00000000
# Covariance (AMZN, AMZN): 0.00842802
# Covariance (AMZN, CRM): 0.00475518
# Covariance (AMZN, GOOG): 0.00423128
# Covariance (AMZN, JNJ): 0.00022789
# Covariance (AMZN, JPM): 0.00063658
# Covariance (AMZN, KO): -0.00022332
# Covariance (AMZN, KR): 0.00086680
# Covariance (AMZN, MCD): 0.00057698
# Covariance (AMZN, META): 0.00397322
# Covariance (AMZN, MSFT): 0.00285777
# Covariance (AMZN, PFE): 0.00036851
# Covariance (AMZN, SLB): 0.00097273
# Covariance (AMZN, TIP): -0.00013846
# Covariance (AMZN, TSLA): 0.00689774
# Covariance (AMZN, V): 0.00239730
# Covariance (CRM, AAPL): 0.00000000
# Covariance (CRM, ACN): 0.00000000
# Covariance (CRM, AMZN): 0.00000000
# Covariance (CRM, CRM): 0.00726803
# Covariance (CRM, GOOG): 0.00000000
# Covariance (CRM, JNJ): 0.00053001
# Covariance (CRM, JPM): 0.00157607
# Covariance (CRM, KO): 0.00056668
# Covariance (CRM, KR): 0.00088967
# Covariance (CRM, MCD): 0.00133230
# Covariance (CRM, META): 0.00000000
# Covariance (CRM, MSFT): 0.00286485
# Covariance (CRM, PFE): 0.00048361
# Covariance (CRM, SLB): 0.00000000
# Covariance (CRM, TIP): 0.00033462
# Covariance (CRM, TSLA): 0.00000000
# Covariance (CRM, V): 0.00265583
# Covariance (GOOG, AAPL): 0.00000000
# Covariance (GOOG, ACN): 0.00000000
# Covariance (GOOG, AMZN): 0.00000000
# Covariance (GOOG, CRM): 0.00366459
# Covariance (GOOG, GOOG): 0.00488848
# Covariance (GOOG, JNJ): 0.00069305
# Covariance (GOOG, JPM): 0.00152995
# Covariance (GOOG, KO): 0.00098687
# Covariance (GOOG, KR): 0.00101370
# Covariance (GOOG, MCD): 0.00104599
# Covariance (GOOG, META): 0.00361479
# Covariance (GOOG, MSFT): 0.00259497
# Covariance (GOOG, PFE): 0.00091566
# Covariance (GOOG, SLB): 0.00232809
# Covariance (GOOG, TIP): 0.00024566
# Covariance (GOOG, TSLA): 0.00456055
# Covariance (GOOG, V): 0.00208797
# Covariance (JNJ, AAPL): 0.00000000
# Covariance (JNJ, ACN): 0.00000000
# Covariance (JNJ, AMZN): 0.00000000
# Covariance (JNJ, CRM): 0.00000000
# Covariance (JNJ, GOOG): 0.00000000
# Covariance (JNJ, JNJ): 0.00598913
# Covariance (JNJ, JPM): 0.00000000
# Covariance (JNJ, KO): 0.00000000
# Covariance (JNJ, KR): 0.00000000
# Covariance (JNJ, MCD): 0.00000000
# Covariance (JNJ, META): 0.00000000
# Covariance (JNJ, MSFT): 0.00398591
# Covariance (JNJ, PFE): 0.00673163
# Covariance (JNJ, SLB): 0.00000000
# Covariance (JNJ, TIP): 0.00362562
# Covariance (JNJ, TSLA): 0.00000000
# Covariance (JNJ, V): 0.00000000
# Covariance (JPM, AAPL): 0.00000000
# Covariance (JPM, ACN): 0.00000000
# Covariance (JPM, AMZN): 0.00000000
# Covariance (JPM, CRM): 0.00000000
# Covariance (JPM, GOOG): 0.00000000
# Covariance (JPM, JNJ): 0.00532255
# Covariance (JPM, JPM): 0.00832821
# Covariance (JPM, KO): 0.00000000
# Covariance (JPM, KR): 0.00000000
# Covariance (JPM, MCD): 0.00000000
# Covariance (JPM, META): 0.00000000
# Covariance (JPM, MSFT): 0.00442179
# Covariance (JPM, PFE): 0.00667948
# Covariance (JPM, SLB): 0.00000000
# Covariance (JPM, TIP): 0.00376046
# Covariance (JPM, TSLA): 0.00000000
# Covariance (JPM, V): 0.00000000
# Covariance (KO, AAPL): 0.00000000
# Covariance (KO, ACN): 0.00000000
# Covariance (KO, AMZN): 0.00000000
# Covariance (KO, CRM): 0.00000000
# Covariance (KO, GOOG): 0.00000000
# Covariance (KO, JNJ): 0.00615936
# Covariance (KO, JPM): 0.00624782
# Covariance (KO, KO): 0.00800951
# Covariance (KO, KR): 0.00000000
# Covariance (KO, MCD): 0.00000000
# Covariance (KO, META): 0.00000000
# Covariance (KO, MSFT): 0.00446714
# Covariance (KO, PFE): 0.00735084
# Covariance (KO, SLB): 0.00000000
# Covariance (KO, TIP): 0.00449319
# Covariance (KO, TSLA): 0.00000000
# Covariance (KO, V): 0.00000000
# Covariance (KR, AAPL): 0.00000000
# Covariance (KR, ACN): 0.00000000
# Covariance (KR, AMZN): 0.00000000
# Covariance (KR, CRM): 0.00000000
# Covariance (KR, GOOG): 0.00000000
# Covariance (KR, JNJ): 0.00372186
# Covariance (KR, JPM): 0.00349706
# Covariance (KR, KO): 0.00411985
# Covariance (KR, KR): 0.00703455
# Covariance (KR, MCD): 0.00351291
# Covariance (KR, META): 0.00000000
# Covariance (KR, MSFT): 0.00280339
# Covariance (KR, PFE): 0.00471196
# Covariance (KR, SLB): 0.00000000
# Covariance (KR, TIP): 0.00270046
# Covariance (KR, TSLA): 0.00000000
# Covariance (KR, V): 0.00000000
# Covariance (MCD, AAPL): 0.00000000
# Covariance (MCD, ACN): 0.00000000
# Covariance (MCD, AMZN): 0.00000000
# Covariance (MCD, CRM): 0.00000000
# Covariance (MCD, GOOG): 0.00000000
# Covariance (MCD, JNJ): 0.00537049
# Covariance (MCD, JPM): 0.00549028
# Covariance (MCD, KO): 0.00645589
# Covariance (MCD, KR): 0.00000000
# Covariance (MCD, MCD): 0.00641982
# Covariance (MCD, META): 0.00000000
# Covariance (MCD, MSFT): 0.00422414
# Covariance (MCD, PFE): 0.00652865
# Covariance (MCD, SLB): 0.00000000
# Covariance (MCD, TIP): 0.00374435
# Covariance (MCD, TSLA): 0.00000000
# Covariance (MCD, V): 0.00000000
# Covariance (META, AAPL): 0.00000000
# Covariance (META, ACN): 0.00000000
# Covariance (META, AMZN): 0.00000000
# Covariance (META, CRM): 0.00389373
# Covariance (META, GOOG): 0.00000000
# Covariance (META, JNJ): 0.00018835
# Covariance (META, JPM): 0.00100998
# Covariance (META, KO): 0.00026333
# Covariance (META, KR): 0.00074613
# Covariance (META, MCD): 0.00052795
# Covariance (META, META): 0.00974885
# Covariance (META, MSFT): 0.00215513
# Covariance (META, PFE): 0.00018299
# Covariance (META, SLB): 0.00000000
# Covariance (META, TIP): 0.00017785
# Covariance (META, TSLA): 0.00000000
# Covariance (META, V): 0.00203934
# Covariance (MSFT, AAPL): 0.00000000
# Covariance (MSFT, ACN): 0.00000000
# Covariance (MSFT, AMZN): 0.00000000
# Covariance (MSFT, CRM): 0.00000000
# Covariance (MSFT, GOOG): 0.00000000
# Covariance (MSFT, JNJ): 0.00000000
# Covariance (MSFT, JPM): 0.00000000
# Covariance (MSFT, KO): 0.00000000
# Covariance (MSFT, KR): 0.00000000
# Covariance (MSFT, MCD): 0.00000000
# Covariance (MSFT, META): 0.00000000
# Covariance (MSFT, MSFT): 0.00559635
# Covariance (MSFT, PFE): 0.00000000
# Covariance (MSFT, SLB): 0.00000000
# Covariance (MSFT, TIP): 0.00257720
# Covariance (MSFT, TSLA): 0.00000000
# Covariance (MSFT, V): 0.00000000
# Covariance (PFE, AAPL): 0.00000000
# Covariance (PFE, ACN): 0.00000000
# Covariance (PFE, AMZN): 0.00000000
# Covariance (PFE, CRM): 0.00000000
# Covariance (PFE, GOOG): 0.00000000
# Covariance (PFE, JNJ): 0.00000000
# Covariance (PFE, JPM): 0.00000000
# Covariance (PFE, KO): 0.00000000
# Covariance (PFE, KR): 0.00000000
# Covariance (PFE, MCD): 0.00000000
# Covariance (PFE, META): 0.00000000
# Covariance (PFE, MSFT): 0.00472566
# Covariance (PFE, PFE): 0.01007917
# Covariance (PFE, SLB): 0.00000000
# Covariance (PFE, TIP): 0.00461973
# Covariance (PFE, TSLA): 0.00000000
# Covariance (PFE, V): 0.00000000
# Covariance (SLB, AAPL): 0.00000000
# Covariance (SLB, ACN): 0.00000000
# Covariance (SLB, AMZN): 0.00000000
# Covariance (SLB, CRM): 0.00234786
# Covariance (SLB, GOOG): 0.00000000
# Covariance (SLB, JNJ): 0.00725920
# Covariance (SLB, JPM): 0.01029660
# Covariance (SLB, KO): 0.00849751
# Covariance (SLB, KR): 0.00484193
# Covariance (SLB, MCD): 0.00707221
# Covariance (SLB, META): 0.00139043
# Covariance (SLB, MSFT): 0.00505867
# Covariance (SLB, PFE): 0.00846395
# Covariance (SLB, SLB): 0.01943127
# Covariance (SLB, TIP): 0.00499378
# Covariance (SLB, TSLA): 0.00542331
# Covariance (SLB, V): 0.00428178
# Covariance (TIP, AAPL): 0.00000000
# Covariance (TIP, ACN): 0.00000000
# Covariance (TIP, AMZN): 0.00000000
# Covariance (TIP, CRM): 0.00000000
# Covariance (TIP, GOOG): 0.00000000
# Covariance (TIP, JNJ): 0.00000000
# Covariance (TIP, JPM): 0.00000000
# Covariance (TIP, KO): 0.00000000
# Covariance (TIP, KR): 0.00000000
# Covariance (TIP, MCD): 0.00000000
# Covariance (TIP, META): 0.00000000
# Covariance (TIP, MSFT): 0.00000000
# Covariance (TIP, PFE): 0.00000000
# Covariance (TIP, SLB): 0.00000000
# Covariance (TIP, TIP): 0.00334628
# Covariance (TIP, TSLA): 0.00000000
# Covariance (TIP, V): 0.00000000
# Covariance (TSLA, AAPL): 0.00000000
# Covariance (TSLA, ACN): 0.00000000
# Covariance (TSLA, AMZN): 0.00000000
# Covariance (TSLA, CRM): 0.00879326
# Covariance (TSLA, GOOG): 0.00000000
# Covariance (TSLA, JNJ): 0.00219342
# Covariance (TSLA, JPM): 0.00295458
# Covariance (TSLA, KO): 0.00206063
# Covariance (TSLA, KR): 0.00199173
# Covariance (TSLA, MCD): 0.00278521
# Covariance (TSLA, META): 0.00628103
# Covariance (TSLA, MSFT): 0.00475363
# Covariance (TSLA, PFE): 0.00180938
# Covariance (TSLA, SLB): 0.00000000
# Covariance (TSLA, TIP): 0.00110388
# Covariance (TSLA, TSLA): 0.03206378
# Covariance (TSLA, V): 0.00335267
# Covariance (V, AAPL): 0.00000000
# Covariance (V, ACN): 0.00000000
# Covariance (V, AMZN): 0.00000000
# Covariance (V, CRM): 0.00000000
# Covariance (V, GOOG): 0.00000000
# Covariance (V, JNJ): 0.00188312
# Covariance (V, JPM): 0.00265713
# Covariance (V, KO): 0.00237184
# Covariance (V, KR): 0.00120248
# Covariance (V, MCD): 0.00236896
# Covariance (V, META): 0.00000000
# Covariance (V, MSFT): 0.00223813
# Covariance (V, PFE): 0.00198867
# Covariance (V, SLB): 0.00000000
# Covariance (V, TIP): 0.00104920
# Covariance (V, TSLA): 0.00000000
# Covariance (V, V): 0.00347476

# %%
# Display the values of the model.expected_return parameter
for asset in model.assets:
    expected_return = model.expected_return[asset]
    print(f"Expected return ({asset}): {expected_return:.8f}")
# Out:
# Expected return (AAPL): -0.03211831
# Expected return (ACN): -0.06295427
# Expected return (AMZN): 0.02154060
# Expected return (CRM): 0.01598724
# Expected return (GOOG): 0.01802565
# Expected return (JNJ): -0.12066369
# Expected return (JPM): -0.12399100
# Expected return (KO): -0.13619245
# Expected return (KR): -0.08654211
# Expected return (MCD): -0.10544409
# Expected return (META): 0.01973888
# Expected return (MSFT): -0.04663647
# Expected return (PFE): -0.16366058
# Expected return (SLB): -0.12281753
# Expected return (TIP): -0.14174854
# Expected return (TSLA): 0.03546088
# Expected return (V): -0.02110278

# %%
# Decision variables
model.w = pe.Var(model.assets, domain = pe.NonNegativeReals, bounds = (0,1))
model.u = pe.Var(model.assets, model.assets, domain = pe.NonNegativeReals)

# %%
# Objective functions

# Maximization 
def calculate_total_return(model):
    '''
    This function calculates the total expected return on investment.

    Parameters
    ----------
    model : Pyomo ConcreteModel
        The optimization model.

    Return
    ------------
    double
        Total expected return.
    '''
    total_return = sum(model.expected_return[i] * model.w[i] for i in model.assets)
    return total_return

# Minimization
def calculate_total_risk(model):
    '''
    This function calculates the total risk of the portfolio.

    Parameters
    ----------
    model : Pyomo ConcreteModel
        The optimization model.

    Return
    ------------
    double
        Total risk.
    '''
    total_risk = sum(model.u[i,j] * model.covariance[i,j] for i in model.assets for j in model.assets)
    return total_risk

# %%
# Constraints
def c_1_weights(model):
    '''
    Ensures the total weight sums up to one.

    Parameters
    ----------
    model : Pyomo ConcreteModel
        The optimization model.

    Returns
    -------
    Constraint Expression
        Relational expression for the constraint.
    '''
    weight_left = sum(model.w[i] for i in model.assets)
    weight_right = 1
    weight = (weight_left == weight_right)
    return weight

def c_2_return(model):
    '''
    Ensures the desired level of return of the portfolio is accomplished

    Parameters
    ----------
    model : Pyomo ConcreteModel
        The optimization model.

    Returns
    -------
    Constraint Expression
        Relational expression for the constraint.
    '''
    expected_return_left = sum(model.expected_return[i] * model.w[i] for i in model.assets)
    expected_return_right = model.return_level
    expected_return = (expected_return_left >= expected_return_right)
    return expected_return

def c_3_1_linearized_risk(model):
    '''
    Linearizes the original MPT quadratic constraint by introducing an auxiliary variable.

    Parameters
    ----------

    model : Pyomo ConcreteModel
        The optimization model.

    Returns
    -------
    Constraint Expression
        Relational expression for the constraint.
    '''
    auxiliary_1_left = sum(model.u[i,j] * model.covariance[i,j] for i in model.assets for j in model.assets)
    auxiliary_1_right = model.risk_level
    auxiliary_1 = (auxiliary_1_left <= auxiliary_1_right)
    return auxiliary_1

def c_3_2_linearized_risk(model, i, j):
    '''
    Assigns bounds to the auxiliary variable for the linear convex relaxation (McCormick Envelopes).

    Parameters
    ----------

    model : Pyomo ConcreteMode
        The optimization model.
    i : string
        The assets.
    j : string.
        The assets.

    Returns
    -------
    Constraint Expression
        Relational expression for the constraint.
    '''
    lowBound = 0
    auxiliary_2_left = model.u[i,j]
    auxiliary_2_right = lowBound * model.w[j] + model.w[i] * lowBound  -  lowBound * lowBound
    auxiliary_2 = (auxiliary_2_left >= auxiliary_2_right)
    return auxiliary_2

def c_3_3_linearized_risk(model, i, j):
    '''
    Assigns bounds to the auxiliary variable for the linear convex relaxation (McCormick Envelopes).

    Parameters
    ----------

    model : Pyomo ConcreteMode
        The optimization model.
    i : string
        The assets.
    j : string.
        The assets.

    Returns
    -------
    Constraint Expression
        Relational expression for the constraint.
    '''
    upperBound = 1
    auxiliary_3_left = model.u[i,j]
    auxiliary_3_right = upperBound * model.w[j] + model.w[i] * upperBound  -  upperBound * upperBound
    auxiliary_3 = (auxiliary_3_left >= auxiliary_3_right)
    return auxiliary_3

def c_3_4_linearized_risk(model, i, j):
    '''
    Assigns bounds to the auxiliary variable for the linear convex relaxation (McCormick Envelopes).

    Parameters
    ----------

    model : Pyomo ConcreteMode
        The optimization model.
    i : string
        The assets.
    j : string.
        The assets.

    Returns
    -------
    Constraint Expression
        Relational expression for the constraint.
    '''
    lowBound = 0
    upperBound = 1
    auxiliary_4_left = model.u[i,j]
    auxiliary_4_right = upperBound * model.w[j] + model.w[i] * lowBound  -  upperBound * lowBound
    auxiliary_4 = (auxiliary_4_left <= auxiliary_4_right)
    return auxiliary_4

def c_3_5_linearized_risk(model, i, j):
    '''
    Assigns bounds to the auxiliary variable for the linear convex relaxation (McCormick Envelopes).

    Parameters
    ----------

    model : Pyomo ConcreteMode
        The optimization model.
    i : string
        The assets.
    j : string.
        The assets.

    Returns
    -------
    Constraint Expression
        Relational expression for the constraint.
    '''
    lowBound = 0
    upperBound = 1
    auxiliary_5_left = model.u[i,j]
    auxiliary_5_right = model.w[i] * upperBound  + lowBound * model.w[j]  -  lowBound * upperBound
    auxiliary_5 = (auxiliary_5_left <= auxiliary_5_right)
    return auxiliary_5

def c_4_non_negative(model, i):
    '''
    Non negativity in the decision variable.

    Parameters
    ----------

    model : Pyomo ConcreteMode
        The optimization model.
    i : string
        The assets.
    j : string.
        The assets.

    Returns
    -------
    Constraint Expression
        Relational expression for the constraint.
    '''
    non_negative_left = model.w[i]
    non_negatiave_right = 0
    non_negative = (non_negative_left >= non_negatiave_right)
    return non_negative

# %%
# Solve the optimization model

from pyomo.environ import SolverFactory, SolverStatus, TerminationCondition

model.c_1_weights = pe.Constraint(rule = c_1_weights)
model.c_2_return = pe.Constraint(rule = c_2_return)
model.c_3_1_linearized_risk = pe.Constraint(rule = c_3_1_linearized_risk)
model.c_3_2_linearized_risk = pe.Constraint(model.assets, model.assets, rule = c_3_2_linearized_risk)
model.c_3_3_linearized_risk = pe.Constraint(model.assets, model.assets, rule = c_3_3_linearized_risk)
model.c_3_4_linearized_risk = pe.Constraint(model.assets, model.assets, rule = c_3_4_linearized_risk)

model.obj_calculate_total_return = pe.Objective(sense = pe.maximize, rule = calculate_total_return)

solver = pe.SolverFactory('glpk')

# Set the time limit in seconds
time_limit = 600  # 600 seconds

# GLPK configurations
solver.options['tmlim'] = time_limit

# Solve the linear convex problem
result = solver.solve(model, tee = True, report_timing = True)

# Check the solver's termination condition
termination_condition = result.solver.termination_condition
solver_status = result.solver.status

# Print the results or handle them accordingly
if solver_status == SolverStatus.ok and termination_condition == TerminationCondition.optimal:
    print("Optimal solution found.")
    pe.value(model.obj_calculate_total_return)
elif solver_status == SolverStatus.ok and termination_condition in [TerminationCondition.maxTimeLimit]:
    print("Time limit reached. No optimal solution found within the specified time.")
else:
    print("No optimal solution found, model is infeasible or unbounded...")
    print("Solver terminated with condition:", solver_status)
# Out:
#         0.02 seconds required to write file
#         0.02 seconds required for presolve
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --tmlim 600 --write C:\Users\JRODRI~1.VIL\AppData\Local\Temp\tmptd31cyft.glpk.raw
#  --wglp C:\Users\JRODRI~1.VIL\AppData\Local\Temp\tmp3qjwizgp.glpk.glp --cpxlp
#  C:\Users\JRODRI~1.VIL\AppData\Local\Temp\tmph25_j_vt.pyomo.lp
# Reading problem data from 'C:\Users\JRODRI~1.VIL\AppData\Local\Temp\tmph25_j_vt.pyomo.lp'...
# 871 rows, 307 columns, 1905 non-zeros
# 4849 lines were read
# Writing problem data to 'C:\Users\JRODRI~1.VIL\AppData\Local\Temp\tmp3qjwizgp.glpk.glp'...
# 3991 lines were written
# GLPK Simplex Optimizer 5.0
# 871 rows, 307 columns, 1905 non-zeros
# Preprocessing...
# 581 rows, 306 columns, 1615 non-zeros
# Scaling...
#  A: min|aij| =  1.385e-04  max|aij| =  2.000e+00  ratio =  1.445e+04
# GM: min|aij| =  3.753e-01  max|aij| =  2.664e+00  ratio =  7.098e+00
# EQ: min|aij| =  1.431e-01  max|aij| =  1.000e+00  ratio =  6.989e+00
# Constructing initial basis...
# Size of triangular part is 581
#       0: obj =  -8.654211100e-02 inf =   1.442e+00 (2)
#       3: obj =   1.000000000e-02 inf =   0.000e+00 (0)
# *    14: obj =   2.958609626e-02 inf =   2.775e-17 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (847999 bytes)
# Writing basic solution to 'C:\Users\JRODRI~1.VIL\AppData\Local\Temp\tmptd31cyft.glpk.raw'...
# 1187 lines were written
#         0.28 seconds required for solver
#         0.01 seconds required to read logfile
#         0.00 seconds required to read solution file
#         0.02 seconds required for postsolve
# Optimal solution found.

# %%
print("Expected return: ", pe.value(model.obj_calculate_total_return))
# Out:
# Expected return:  0.02958609625582425

# %%
model.w.pprint()
# Out:
# w : Size=17, Index=assets
#     Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#     AAPL :     0 :               0.0 :     1 : False : False : NonNegativeReals
#      ACN :     0 :               0.0 :     1 : False : False : NonNegativeReals
#     AMZN :     0 : 0.422030403194037 :     1 : False : False : NonNegativeReals
#      CRM :     0 :               0.0 :     1 : False : False : NonNegativeReals
#     GOOG :     0 :               0.0 :     1 : False : False : NonNegativeReals
#      JNJ :     0 :               0.0 :     1 : False : False : NonNegativeReals
#      JPM :     0 :               0.0 :     1 : False : False : NonNegativeReals
#       KO :     0 :               0.0 :     1 : False : False : NonNegativeReals
#       KR :     0 :               0.0 :     1 : False : False : NonNegativeReals
#      MCD :     0 :               0.0 :     1 : False : False : NonNegativeReals
#     META :     0 :               0.0 :     1 : False : False : NonNegativeReals
#     MSFT :     0 :               0.0 :     1 : False : False : NonNegativeReals
#      PFE :     0 :               0.0 :     1 : False : False : NonNegativeReals
#      SLB :     0 :               0.0 :     1 : False : False : NonNegativeReals
#      TIP :     0 :               0.0 :     1 : False : False : NonNegativeReals
#     TSLA :     0 : 0.577969596805963 :     1 : False : False : NonNegativeReals
#        V :     0 :               0.0 :     1 : False : False : NonNegativeReals
